# %%
import duckdb

con = duckdb.connect("../data/gold/gold.duckdb", read_only=True)

con.sql("SHOW TABLES").df()
# Out:
#                                name
# 0           mart_area_macro_summary
# 1               mart_daily_activity
# 2    mart_directional_macro_summary
# 3             mart_overview_summary
# 4              mart_region_activity
# 5         mart_weapon_model_summary
# 6          mart_weapon_type_summary
# 7             silver_attack_regions
# 8                    silver_attacks
# 9           silver_weapon_reference
# 10         vw_dashboard_area_macros
# 11      vw_dashboard_daily_activity
# 12  vw_dashboard_directional_macros
# 13            vw_dashboard_overview
# 14          vw_dashboard_region_map
# 15       vw_dashboard_weapon_models
# 16        vw_dashboard_weapon_types

# %%
con.sql("SELECT * FROM mart_overview_summary").df()
# Out:
#   first_event_date last_event_date  total_attack_rows  distinct_event_dates  \
# 0       2022-09-28      2026-04-10               3597                  1066
#
#    distinct_weapon_models  distinct_weapon_categories  total_launched  \
# 0                      70                           7        100825.0
#
#    total_destroyed  total_not_reach_goal  total_still_attacking  \
# 0          73795.0               13052.0                  499.0
#
#    nationwide_launched_total  specific_area_launched_total  \
# 0                    90589.0                        3724.0
#
#    unknown_target_rows  unmatched_weapon_reference_rows
# 0                 30.0                              9.0

# %%
con.sql("""
SELECT *
FROM mart_daily_activity
ORDER BY event_date
LIMIT 20
""").df()
# Out:
#    event_date  attack_rows  distinct_weapon_models  launched_total  \
# 0  2022-09-28            2                       2             8.0
# 1  2022-09-29            1                       1             7.0
# 2  2022-09-30            1                       1             3.0
# 3  2022-10-01            1                       1             1.0
# 4  2022-10-02            1                       1             7.0
# 5  2022-10-05            3                       2             8.0
# 6  2022-10-06            6                       3            17.0
# 7  2022-10-07            1                       1             3.0
# 8  2022-10-08            2                       2             3.0
# 9  2022-10-09            3                       3            22.0
# 10 2022-10-10            3                       3           108.0
# 11 2022-10-11            4                       2            62.0
# 12 2022-10-12            2                       2            19.0
# 13 2022-10-13            2                       2            11.0
# 14 2022-10-14            1                       1             8.0
# 15 2022-10-15            1                       1             6.0
# 16 2022-10-16            1                       1            11.0
# 17 2022-10-17            5                       3            39.0
# 18 2022-10-18            3                       3            11.0
# 19 2022-10-19            3                       2            29.0
#
#     destroyed_total  not_reach_goal_total  still_attacking_total  \
# 0               7.0                   0.0                    0.0
# 1               5.0                   0.0                    0.0
# 2               3.0                   0.0                    0.0
# 3               1.0                   0.0                    0.0
# 4               5.0                   0.0                    0.0
# 5               8.0                   0.0                    0.0
# 6              17.0                   0.0                    0.0
# 7               3.0                   0.0                    0.0
# 8               3.0                   0.0                    0.0
# 9               1.0                   0.0                    0.0
# 10             56.0                   0.0                    0.0
# 11             54.0                   0.0                    0.0
# 12             19.0                   0.0                    0.0
# 13             11.0                   0.0                    0.0
# 14              8.0                   0.0                    0.0
# 15              6.0                   0.0                    0.0
# 16             11.0                   0.0                    0.0
# 17             39.0                   0.0                    0.0
# 18             11.0                   0.0                    0.0
# 19             27.0                   0.0                    0.0
#
#     launched_7d_avg  destroyed_7d_avg
# 0          8.000000          7.000000
# 1          7.500000          6.000000
# 2          6.000000          5.000000
# 3          4.750000          4.000000
# 4          5.200000          4.200000
# 5          5.666667          4.833333
# 6          7.285714          6.571429
# 7          6.571429          6.000000
# 8          6.000000          5.714286
# 9          8.714286          5.428571
# 10        24.000000         13.285714
# 11        31.857143         20.285714
# 12        33.428571         21.857143
# 13        32.571429         21.000000
# 14        33.285714         21.714286
# 15        33.714286         22.142857
# 16        32.142857         23.571429
# 17        22.285714         21.142857
# 18        15.000000         15.000000
# 19        16.428571         16.142857

# %%
con.sql("""
SELECT *
FROM mart_weapon_model_summary
ORDER BY launched_total DESC
LIMIT 20
""").df()
# Out:
#                             weapon_model         weapon_category  \
# 0                         Shahed-136/131                     UAV
# 1                                Unknown                   Mixed
# 2                            X-101/X-555          cruise missile
# 3                                 Молнія                     UAV
# 4                 X-101/X-555 and Kalibr          cruise missile
# 5                                 Kalibr          cruise missile
# 6                             Iskander-M       ballistic missile
# 7                     Reconnaissance UAV                     UAV
# 8                       Iskander-M/KN-23       ballistic missile
# 9                                 Lancet                     UAV
# 10                                 C-300  surface-to-air missile
# 11                                  ZALA                     UAV
# 12                             X-59/X-69          cruise missile
# 13                                  X-59          cruise missile
# 14                              Orlan-10                     UAV
# 15                              Supercam                     UAV
# 16                          X-47 Kinzhal       ballistic missile
# 17                            Iskander-K          cruise missile
# 18                                  X-22          cruise missile
# 19  X-101/X-555 and Kalibr and X-59/X-69          cruise missile
#
#                                           weapon_type  attack_rows  \
# 0                                  loitering munition          991
# 1                                        Unknown type          290
# 2                                        air-launched          102
# 3                                        Unknown type          112
# 4                                        Unknown type            9
# 5                                        Unknown type           73
# 6                                 TV-guided, tactical          264
# 7                                      reconnaissance          200
# 8                                        Unknown type           83
# 9                                  loitering munition          143
# 10                            santi-ballistic missile           80
# 11                                     reconnaissance          175
# 12                                       Unknown type          107
# 13  air-launched, air-to-surface, anti-ship, land-...          154
# 14                                     reconnaissance          201
# 15                                     reconnaissance          178
# 16                                       air-launched           70
# 17                                       Unknown type           59
# 18                                     air-to-surface           38
# 19                                       Unknown type            2
#
#     active_days  launched_total  destroyed_total  matched_rows  \
# 0           913         87875.0          63761.0         991.0
# 1           285          3471.0           3390.0         290.0
# 2           101          1994.0           1708.0         102.0
# 3           112           811.0            811.0         112.0
# 4             9           643.0            508.0           9.0
# 5            72           557.0            433.0          73.0
# 6           236           482.0             71.0         264.0
# 7           199           460.0            459.0         200.0
# 8            78           364.0             90.0          83.0
# 9           143           355.0            355.0         143.0
# 10           80           345.0              2.0          80.0
# 11          162           309.0            308.0         175.0
# 12          100           292.0            191.0         107.0
# 13          141           269.0            166.0         154.0
# 14          175           267.0            266.0         201.0
# 15          160           252.0            251.0         178.0
# 16           65           225.0             64.0          70.0
# 17           59           212.0            139.0          59.0
# 18           37           157.0              3.0          38.0
# 19            2           157.0            126.0           2.0
#
#     unmatched_rows  reference_coverage_pct  launched_share_pct  \
# 0              0.0                   100.0               87.16
# 1              0.0                   100.0                3.44
# 2              0.0                   100.0                1.98
# 3              0.0                   100.0                0.80
# 4              0.0                   100.0                0.64
# 5              0.0                   100.0                0.55
# 6              0.0                   100.0                0.48
# 7              0.0                   100.0                0.46
# 8              0.0                   100.0                0.36
# 9              0.0                   100.0                0.35
# 10             0.0                   100.0                0.34
# 11             0.0                   100.0                0.31
# 12             0.0                   100.0                0.29
# 13             0.0                   100.0                0.27
# 14             0.0                   100.0                0.26
# 15             0.0                   100.0                0.25
# 16             0.0                   100.0                0.22
# 17             0.0                   100.0                0.21
# 18             0.0                   100.0                0.16
# 19             0.0                   100.0                0.16
#
#     destroyed_to_launched_pct first_seen  last_seen
# 0                       72.56 2022-09-29 2026-04-10
# 1                       97.67 2022-10-08 2026-04-10
# 2                       85.66 2022-10-18 2026-04-03
# 3                      100.00 2025-01-09 2026-02-17
# 4                       79.00 2022-10-10 2025-05-25
# 5                       77.74 2022-10-13 2026-03-14
# 6                       14.73 2023-05-22 2026-04-02
# 7                       99.78 2022-09-28 2026-03-29
# 8                       24.73 2024-02-15 2025-12-13
# 9                      100.00 2022-10-12 2025-10-25
# 10                       0.58 2022-10-09 2025-11-03
# 11                      99.68 2023-05-08 2025-11-15
# 12                      65.41 2024-04-19 2026-03-23
# 13                      61.71 2022-09-28 2025-10-15
# 14                      99.63 2022-09-30 2026-01-09
# 15                      99.60 2023-04-08 2025-06-29
# 16                      28.44 2023-01-26 2026-03-28
# 17                      65.57 2023-05-17 2026-04-02
# 18                       1.91 2022-10-09 2026-03-09
# 19                      80.25 2024-08-26 2025-09-09

# %%
con.sql("""
SELECT *
FROM mart_area_macro_summary
ORDER BY launched_total DESC
""").df()
# Out:
#        area_macro                target_scope  attack_rows  active_days  \
# 0      nationwide                  nationwide         1485          817
# 1           south  directional_or_other_macro          973          521
# 2           south          specific_area_rows          526          338
# 3           multi          specific_area_rows           57           50
# 4           north          specific_area_rows           53           42
# 5     center-east          specific_area_rows          175          141
# 6            east          specific_area_rows           97           79
# 7            east  directional_or_other_macro           91           62
# 8           multi  directional_or_other_macro            9            9
# 9         unknown                     unknown           30           21
# 10           west  directional_or_other_macro            8            8
# 11    center-west          specific_area_rows           14           13
# 12     south-east          specific_area_rows           29           21
# 13     north-east          specific_area_rows           20           18
# 14     south-east  directional_or_other_macro            5            5
# 15           west          specific_area_rows            8            8
# 16          north  directional_or_other_macro            7            7
# 17         center          specific_area_rows            3            3
# 18  international          specific_area_rows            2            2
# 19     front line  directional_or_other_macro            2            1
# 20     north-east  directional_or_other_macro            2            1
# 21         center  directional_or_other_macro            1            1
#
#     launched_total  destroyed_total  launched_share_pct
# 0          90589.0          65050.0               89.85
# 1           5627.0           5602.0                5.58
# 2           1430.0            947.0                1.42
# 3            875.0            589.0                0.87
# 4            572.0            514.0                0.57
# 5            314.0            214.0                0.31
# 6            295.0             97.0                0.29
# 7            281.0            175.0                0.28
# 8            241.0            187.0                0.24
# 9            192.0            133.0                0.19
# 10            94.0             91.0                0.09
# 11            73.0             51.0                0.07
# 12            66.0             29.0                0.07
# 13            54.0             25.0                0.05
# 14            34.0             33.0                0.03
# 15            32.0             16.0                0.03
# 16            28.0             21.0                0.03
# 17             7.0              5.0                0.01
# 18             6.0              1.0                0.01
# 19             5.0              5.0                0.00
# 20             5.0              5.0                0.00
# 21             5.0              5.0                0.00

# %%
con.sql("SELECT * FROM vw_dashboard_daily_activity LIMIT 20").df()
# Out:
#    event_date  attack_rows  distinct_weapon_models  launched_total  \
# 0  2022-09-28            2                       2             8.0
# 1  2022-09-29            1                       1             7.0
# 2  2022-09-30            1                       1             3.0
# 3  2022-10-01            1                       1             1.0
# 4  2022-10-02            1                       1             7.0
# 5  2022-10-05            3                       2             8.0
# 6  2022-10-06            6                       3            17.0
# 7  2022-10-07            1                       1             3.0
# 8  2022-10-08            2                       2             3.0
# 9  2022-10-09            3                       3            22.0
# 10 2022-10-10            3                       3           108.0
# 11 2022-10-11            4                       2            62.0
# 12 2022-10-12            2                       2            19.0
# 13 2022-10-13            2                       2            11.0
# 14 2022-10-14            1                       1             8.0
# 15 2022-10-15            1                       1             6.0
# 16 2022-10-16            1                       1            11.0
# 17 2022-10-17            5                       3            39.0
# 18 2022-10-18            3                       3            11.0
# 19 2022-10-19            3                       2            29.0
#
#     destroyed_total  not_reach_goal_total  still_attacking_total  \
# 0               7.0                   0.0                    0.0
# 1               5.0                   0.0                    0.0
# 2               3.0                   0.0                    0.0
# 3               1.0                   0.0                    0.0
# 4               5.0                   0.0                    0.0
# 5               8.0                   0.0                    0.0
# 6              17.0                   0.0                    0.0
# 7               3.0                   0.0                    0.0
# 8               3.0                   0.0                    0.0
# 9               1.0                   0.0                    0.0
# 10             56.0                   0.0                    0.0
# 11             54.0                   0.0                    0.0
# 12             19.0                   0.0                    0.0
# 13             11.0                   0.0                    0.0
# 14              8.0                   0.0                    0.0
# 15              6.0                   0.0                    0.0
# 16             11.0                   0.0                    0.0
# 17             39.0                   0.0                    0.0
# 18             11.0                   0.0                    0.0
# 19             27.0                   0.0                    0.0
#
#     launched_7d_avg  destroyed_7d_avg
# 0          8.000000          7.000000
# 1          7.500000          6.000000
# 2          6.000000          5.000000
# 3          4.750000          4.000000
# 4          5.200000          4.200000
# 5          5.666667          4.833333
# 6          7.285714          6.571429
# 7          6.571429          6.000000
# 8          6.000000          5.714286
# 9          8.714286          5.428571
# 10        24.000000         13.285714
# 11        31.857143         20.285714
# 12        33.428571         21.857143
# 13        32.571429         21.000000
# 14        33.285714         21.714286
# 15        33.714286         22.142857
# 16        32.142857         23.571429
# 17        22.285714         21.142857
# 18        15.000000         15.000000
# 19        16.428571         16.142857

# %%
con.sql("""
SELECT schema_name
FROM information_schema.schemata;
""").df()
# Out:
# ---------------------------------------------------------------------------
# InvalidInputException                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 con.sql("""
#       2     SELECT *
#       3     FROM gold.duckdb
#       4     ORDER BY launched_total DESC, attack_rows DESC
#
# InvalidInputException: Invalid Input Error: Python Object "duckdb" of type "module" found on line "C:\temp\ipykernel_44996\1644466061.py:1" not suitable for replacement scans.
# Make sure that "duckdb" is either a pandas.DataFrame, duckdb.DuckDBPyRelation, pyarrow Table, Dataset, RecordBatchReader, Scanner, or NumPy ndarrays with supported format
